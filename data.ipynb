# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/Semantic-Segmentation')

# %%
import numpy as np
import tensorflow as tf

import utils

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2

# %%
## Paths ======================================
IMAGES_MAT = 'data/images_mat/'
IMAGES_PNG = 'data/images_png/'
LABELS_MAT = 'data/labels_mat/'
LABELS_PNG = 'data/labels_png/'

TRAIN_MAT = 'data/train_mat.txt'
TRAIN_PNG = 'data/train_png.txt'
VAL_MAT = 'data/val_mat.txt'

TRAIN = 'data/train.tfrecords'
VAL = 'data/val.tfrecords'
## ============================================

# %%
## write train dataset
with tf.io.TFRecordWriter(TRAIN) as writer:
    ## write .mat files
    with open(TRAIN_MAT) as file:
        filenames = [s.rstrip('\n') for s in file.readlines()]
    for name in filenames:
        image = utils.get_image(IMAGES_MAT+name+'.jpg')
        label = utils.get_label_mat(LABELS_MAT+name+'.mat')
        writer.write(utils.get_example(image, label).SerializeToString())
    ## write .png files
    with open(TRAIN_PNG) as file:
        filenames = [s.rstrip('\n') for s in file.readlines()]
    for name in filenames:
        image = utils.get_image(IMAGES_PNG+name+'.jpg')
        label = utils.get_label_png(LABELS_PNG+name+'.png')
        writer.write(utils.get_example(image, label).SerializeToString())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-d4bbbbddb282> in <module>
#       5         filenames = [s.rstrip('\n') for s in file.readlines()]
#       6     for name in filenames:
# ----> 7         image = utils.get_image(IMAGES_MAT+name+'.jpg')
#       8         label = utils.get_label_mat(LABELS_MAT+name+'.mat')
#       9         writer.write(utils.get_example(image, label).SerializeToString())
#
# /content/drive/MyDrive/Colab Notebooks/Semantic-Segmentation/utils.py in get_image(path)
#      66       (array<np.uint8>): RGB values for each pixel. Shape=(height, width, 3)
#      67     '''
# ---> 68     jpg = Image.open(path).convert('RGB')
#      69     return np.array(jpg)
#      70
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/images_mat/2008_000002.jpg'

# %%
## write validation dataset
with tf.io.TFRecordWriter(VAL) as writer:
    ## write .mat files
    with open(VAL_MAT) as file:
        filenames = [s.rstrip('\n') for s in file.readlines()]
    for name in filenames:
        image = utils.get_image(IMAGES_MAT+name+'.jpg')
        label = utils.get_label_mat(LABELS_MAT+name+'.mat')
        writer.write(utils.get_example(image, label).SerializeToString())
